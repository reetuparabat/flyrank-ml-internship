# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/reetuparabat/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
'''I chose Lane 2: Content Refresh Opportunity Scoring because it focuses on identifying content that may need to be refreshed or improved based on its performance.
Instead of reviewing every page manually, I want to use data to help identify which pages are more likely to benefit from an update.'''
# Out:
# 'I chose Lane 2: Content Refresh Opportunity Scoring because it focuses on identifying content that may need to be refreshed or improved based on its performance.\nInstead of reviewing every page manually, I want to use data to help identify which pages are more likely to benefit from an update.'

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
'''the decision is to identify which pages shouldd be refreshed.
A content manager or SEO manager uses the recommendations to decide which pages should be reviewed and updated first.
A wrong recommendation could waste time and resources by updating pages that are already performing well.
At the same time, pages that actually need improvement may be ignored, which could reduce the overall effectiveness of the website.'''
# Out:
# 'the decision is to identify which pages shouldd be refreshed.\nA content manager or SEO manager uses the recommendations to decide which pages should be reviewed and updated first.\nA wrong recommendation could waste time and resources by updating pages that are already performing well.\nAt the same time, pages that actually need improvement may be ignored, which could reduce the overall effectiveness of the website.'

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv(
    "flyrank-ml-internship/data/raw/content_refresh_anonymized.csv"
)
df.head()
print(df.shape)

print(df.columns)

print(df["trend_direction"].value_counts())

print(df["client_id"].nunique())

print('''The dataset contains 30,000 content records from 32 different clients.
I also found that 16,262 pages (about 54% of the dataset) are currently trending downward.
This shows that reviewing every page manually would take a lot of time.
Using data can help identify which pages should be reviewed first, making the process more efficient.''')
# Out:
# (30000, 44)
# Index(['content_id', 'client_id', 'search_volume', 'competition',
#        'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count',
#        'char_count', 'provider_used', 'model_used', 'impressions_90d',
#        'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d',
#        'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d',
#        'days_with_impressions', 'days_with_sessions', 'impressions_last_30d',
#        'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d',
#        'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier',
#        'age_tier_order', 'days_since_last_update', 'freshness_tier',
#        'word_count_tier', 'char_count_tier', 'ctr', 'avg_position',
#        'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier',
#        'position_tier', 'trend_direction', 'trend_pct'],
#       dtype='object')
# trend_direction
# down      16262
# stable     5962
# up         4388
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
'''My work can help identify pages that may benefit from being reviewed or updated based on the available data.
It supports decision-making, but it cannot guarantee better rankings or predict how Google will rank a page after it is updated.'''
# Out:
# 'My work can help identify pages that may benefit from being reviewed or updated based on the available data.\nIt supports decision-making, but it cannot guarantee better rankings or predict how Google will rank a page after it is updated.'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
